# %%
import requests
from bs4 import BeautifulSoup
import csv

url = 'https://aopwiki.org/events'  # ← Replace this with your actual URL
response = requests.get(url, verify=False)
soup = BeautifulSoup(response.text, 'html.parser')

table = soup.find('table')
rows = table.find_all('tr')

output = []

for row in rows:
    cols = row.find_all(['td', 'th'])

    # Extract raw elements for processing
    col_elements = [col for col in cols]

    # Check if any <td> contains <li>
    if any(col.find('li') for col in col_elements):
        # Find the column(s) with <li>s
        list_col_index = [i for i, col in enumerate(col_elements) if col.find('li')]

        # Assume only one column contains <li>s (can extend if needed)
        for li in col_elements[list_col_index[0]].find_all('li'):
            new_row = []
            for i, col in enumerate(col_elements):
                if i in list_col_index:
                    new_row.append(li.get_text(strip=True))
                else:
                    new_row.append(col.get_text(strip=True))
            output.append(new_row)
    else:
        # Normal row
        output.append([col.get_text(strip=True) for col in col_elements])

# Write to CSV
with open('events.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerows(output)
# Out:
# /home/minsul/anaconda3/envs/aop/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aopwiki.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
import pandas as pd

df = pd.read_csv('events.csv')

df
# Out:
#         ID                                              Title  \
# 0     2157            Abnormal Cardiac Structure and Function
# 1     2284                Increased Intracellular cAMP Levels
# 2     2264  Lysolecithin cell membrane integration, increased
# 3     2263                            Lysolecithin, increased
# 4     2263                            Lysolecithin, increased
# ...    ...                                                ...
# 3576  1107                                   Weakened, Colony
# 3577  1107                                   Weakened, Colony
# 3578  1107                                   Weakened, Colony
# 3579  1645                             Wnt ligand stimulation
# 3580  1648                               β-catenin activation
#
#      Biological organization Creation Date  Last Updated  \
# 0                      Organ  Jul 31, 2023  Jul 31, 2023
# 1                   Cellular  Nov 21, 2024  Nov 21, 2024
# 2                   Cellular   Oct 1, 2024   Oct 1, 2024
# 3                   Cellular   Oct 1, 2024   Oct 1, 2024
# 4                   Cellular   Oct 1, 2024   Oct 1, 2024
# ...                      ...           ...           ...
# 3576              Population  Nov 29, 2016   Jun 7, 2018
# 3577              Population  Nov 29, 2016   Jun 7, 2018
# 3578              Population  Nov 29, 2016   Jun 7, 2018
# 3579               Molecular  May 28, 2019  May 29, 2019
# 3580               Molecular  May 29, 2019  May 29, 2019
#
#                                                    AOPs
# 0         β2-Receptor agonist leading to Cardiomyopathy
# 1     β-adrenergic receptor agonists leading to arrh...
# 2     Inhibition of neuropathy target esterase leadi...
# 3     Inhibition of neuropathy target esterase leadi...
# 4     Inhibition of neuropathy target esterase leadi...
# ...                                                 ...
# 3576  Nosema infection increases energetic demands l...
# 3577  Nosema infection causes abnormal role change t...
# 3578  Queen egg-laying decrease leads to colony loss...
# 3579                                                NaN
# 3580                                                NaN
#
# [3581 rows x 6 columns]
